# %% [markdown]
# **Packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Packages form Henriks Github
from lammps_logfile import running_mean, get_color_value
from regex_file_collector import Collector
from regex_file_collector.utils import floating_number_pattern
import lammps_logfile

# %% [markdown]
# **Choose folder**

# %%
path = '/home/users/marthgg/2021_08_quartz_simulations'
#path = '/home/users/marthgg/2021_11_rotate'
pattern = 'crack_simulation_'+floating_number_pattern('deformZ')+'/fracture_displacement.npy'

collection = Collector(path, pattern, fields=('deformZ'))
simulations = collection.get_flat()

logFileFolder = '/home/users/marthgg/2021_08_quartz_simulations'
# Out:
# The pattern contains 1 capturing groups
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.025391/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.037500/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.023591/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.011000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.018000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.027194/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.050000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.043812/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.03499/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.019855/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.032990/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.049555/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.038927/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.041904/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.035994/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.040000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.039854/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.038000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.031994/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.010000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.020000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.030000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.033992/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.045723/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.047637/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.016245/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.029000/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.029806/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.021794/fracture_displacement.npy
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.036997/fracture_displacement.npy

# %% [markdown]
# **Save figure**

# %%
def save_figure(output_file_name):
    plt.savefig(output_file_name, dpi=None, facecolor='w', edgecolor='w', orientation='portrait')

# %% [markdown]
# **Filter data and make plots**

# %%
system_length = 3000
crack_start_point = 150

for deformZ, path in simulations.items():
        
    filename = path

    data = np.load(filename, allow_pickle=False)
    frames = list(range(0, len(data)))

    filtered_data_crackTip = []
    filtered_data_frames   = []

    for i in range(0, len(data)):
        if data[i] > crack_start_point and data[i] < system_length:
            filtered_data_crackTip.append(data[i])
            filtered_data_frames.append(frames[i])            
    
    for i in range(0, len(filtered_data_frames)):
        if filtered_data_crackTip[i] > 2910:
            print(filename)
            print(filtered_data_frames[i])
            break

    # Find velocity
    timestep = 0.001 # ps
    dump_frequency = 10000

    time_s = []
    time = []
    for i in range(0, len(filtered_data_frames)):
        time.append(filtered_data_frames[i]*timestep*dump_frequency) #Time in ps
        if filtered_data_crackTip[i] < 2910:
            time_s.append(filtered_data_frames[i]*timestep*dump_frequency*(10**-12)) #time in s

    position_m = []
    for i in range(0, len(filtered_data_crackTip)):
        if filtered_data_crackTip[i] < 2910:
            position_m.append(filtered_data_crackTip[i]*(10**-10)) #distance in m

    velocity = np.diff(position_m)/np.diff(time_s)
    mean_velocity = np.mean(velocity)
   
    plt.figure(1)
    plt.plot(filtered_data_frames, filtered_data_crackTip, color=get_color_value(float(deformZ), 1.010000, 1.050000))
    plt.xlabel('Time (ps)')
    plt.ylabel('Position x')
    
    #save_figure('/home/users/marthgg/2021_11_figures/velocities.ps')
    
    logfile = os.path.join(logFileFolder, 'crack_simulation_deformZ_%s/log.lammps') %deformZ

    log = lammps_logfile.File(logfile)
    pzz = log.get('Pzz')
    min_pressure = np.min(pzz)
    
    potEng = log.get('PotEng')
    time = log.get('Time')
    
    Cs = 3805 # Rayleigh wave speed
    Vr = mean_velocity/Cs
    
    #fig = plt.figure(2)
    #ax1 = fig.add_subplot()
    
    #ax1.set_xlabel('Initial tensile stress (MPa)')
    #ax1.set_ylabel('Rupture velocity (m/s)', color='k')
    #ax1.plot((min_pressure/10)*-1, mean_velocity, 'o', color=get_color_value(float(deformZ), 1.010000, 1.050000))
    #ax1.tick_params(axis='y', labelcolor='k')
    #ax1.set_xlim([800, 2200])
    #ax1.set_ylim([300, 1100])
    
    #ax2 = ax1.twinx()
    #ax2.set_ylabel('Vr/Cs (m/s)', color='r')  # we already handled the x-label with ax1
    #ax2.plot((min_pressure/10)*-1, Vr, 'o', color=get_color_value(float(deformZ), 1.010000, 1.050000))
    #ax2.tick_params(axis='y', labelcolor='r')
    #ax2.set_ylim([0.01, 0.8])
    #fig.tight_layout()
    
    
    plt.figure(2)
    plt.plot((min_pressure/10)*-1, mean_velocity, 'o', color=get_color_value(float(deformZ), 1.010000, 1.050000))
    plt.xlabel('Initial tensile stress (MPa)')
    plt.ylabel('Rupture velocity (m/s)')
    
    #save_figure('/home/users/marthgg/2021_11_figures/velocities.ps')    
    
    min_pot = np.min(potEng)
    pot = potEng[200:]
    min_pot_crack = np.min(pot[100:])
    
    delta_up = min_pot_crack - min_pot #eV
    delta_up_J = delta_up * 1.60218e-19 #Joules

    plt.figure(3)
    plt.plot(mean_velocity, delta_up_J, 'o', color=get_color_value(float(deformZ), 1.010000, 1.050000))
    plt.ylabel('Change in potential energy (J)')
    plt.xlabel('Crack tip velocity (m/s)')
    
    #save_figure('/home/users/marthgg/2021_11_figures/potential_energy.ps')
    
    #if filtered_data_crackTip[-1] > 2800:
    plt.figure(4)
    plt.plot(time/10, potEng*1.60218e-19, color=get_color_value(float(deformZ), 1.010000, 1.050000))#, cmap='jet'))
    plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
    plt.ylabel('Potential energy (J)')
    plt.xlabel('Time (ps)')
    
    if mean_velocity > 400: #Remove values when the crack is not propagating
        plt.figure(5)
        plt.plot(time/10, potEng*1.60218e-19, color=get_color_value(float(deformZ), 1.010000, 1.050000))#, cmap='jet'))
        plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
        plt.ylabel('Potential energy (J)')
        plt.xlabel('Time (ps)')

    
    #save_figure('/home/users/marthgg/img/noRot_velocities_vs_potentialEnergy.png')
# Out:
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.037500/fracture_displacement.npy
# 26
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.027194/fracture_displacement.npy
# 44
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.050000/fracture_displacement.npy
# 23
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.043812/fracture_displacement.npy
# 22
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.03499/fracture_displacement.npy
# 27
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.032990/fracture_displacement.npy
# 33
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.049555/fracture_displacement.npy
# 21
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.038927/fracture_displacement.npy
# 24
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.041904/fracture_displacement.npy
# 21
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.035994/fracture_displacement.npy
# 27
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.040000/fracture_displacement.npy
# 25
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.039854/fracture_displacement.npy
# 24
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.038000/fracture_displacement.npy
# 26
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.031994/fracture_displacement.npy
# 35
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/users/marthgg/.pyenv/versions/md_analysis/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.030000/fracture_displacement.npy
# 43
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.033992/fracture_displacement.npy
# 30
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.045723/fracture_displacement.npy
# 20
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.047637/fracture_displacement.npy
# 20
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.029000/fracture_displacement.npy
# 41
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.029806/fracture_displacement.npy
# 40
# /home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.036997/fracture_displacement.npy
# 26
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:105: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
# <ipython-input-11-a6a4e4fd0ddb>:112: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.axhline(min_pot*1.60218e-19, color='k', LineStyle='--')
