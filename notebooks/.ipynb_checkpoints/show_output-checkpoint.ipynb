# %%
import ase.spacegroup
from molecular_builder.core import write

from IPython.display import Image

# %%
from ovito.vis import Viewport, TachyonRenderer
from ovito.io import import_file

filename = '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.076575/crack.data'
pipeline = import_file(filename)
pipeline.add_to_scene()

vp = Viewport()
tachyon = TachyonRenderer(shadows=False, direct_light_intensity=1.1)
vp.render_image(filename="figure.png", background=(0,0,0), renderer=tachyon)

Image("figure.png")
