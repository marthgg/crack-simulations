# %%
import lammps_logfile
from regex_file_collector import Collector
from regex_file_collector.utils import floating_number_pattern
import matplotlib.pyplot as plt
from lammps_logfile import get_color_value

# %%
def save_figure(output_file_name):
    plt.savefig(output_file_name, dpi=None, facecolor='w', edgecolor='w', orientation='portrait')

# %%
#paths1 = ['/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.042714/log.lammps', '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.024721/log.lammps', '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.021159/log.lammps', '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.046351/log.lammps', '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.035479/log.lammps', '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.031881/log.lammps', '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.039091/log.lammps', '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.028294/log.lammps']

#paths2 = [
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.042714/increase_lz/log.lammps',
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.024721/increase_lz/log.lammps',
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.021159/increase_lz/log.lammps',
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.046351/increase_lz/log.lammps',
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.035479/increase_lz/log.lammps',
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.031881/increase_lz/log.lammps',
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.039091/increase_lz/log.lammps',
#    '/home/users/marthgg/simulations/rotated/angle_30/crack_simulation_deformZ_1.028294/increase_lz/log.lammps']

    
#paths1 = ['/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.053649/log.lammps']
#paths2 = ['/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.053649/increase_lz/log.lammps']

paths1 = [
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.042714/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.053649/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.056894/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.066689/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.050000/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.076575/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.046351/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.063414/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.069974/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.093256/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.083217/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.035479/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.089899/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.031881/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.086553/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.039091/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.100000/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.060149/log.lammps',
    '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.028294/log.lammps']

for path1 in paths1:
    filename = path1
    print(filename)
    log = lammps_logfile.File(filename)
    
    time = log.get('Time')
    
    pot = log.get('PotEng')
    pzz = log.get('Pzz')
    temp = log.get('Temp')
    
    plt.figure(1)
    plt.plot(time, pzz)
    
    plt.figure(2)
    plt.plot(time, pot)
    
    #filename = path2
    #log = lammps_logfile.File(filename)
    
    #time = log.get('Time')+time[-1]
    
    #pot = log.get('PotEng')
    #pzz = log.get('Pzz')
    #temp = log.get('Temp')
    
    
    #plt.figure(1)
    #plt.plot(time, pzz)
    #plt.xlim([440, 500])
    #plt.ylim([-8.14e6, -8.13e6])
    
    #plt.figure(2)
    #plt.plot(time, pot)
    #plt.xlim([420, 500])
    #plt.ylim([-8.4175e6, -8.41e6])
# Out:
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.042714/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.053649/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.056894/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.066689/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.050000/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.076575/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.046351/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.063414/log.lammps
# ...

# %%
path = '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30'
pattern = 'crack_simulation_'+floating_number_pattern('deformZ')+'/log.lammps'

collection = Collector(path, pattern, fields=('deformZ'))
simulations = collection.get_flat()

for deformZ, path in simulations.items():
    
    #if float(deformZ) == 1.046351 or float(deformZ) == 1.066689 or float(deformZ) == 1.086553:
        filename = path
        print(filename)
        log = lammps_logfile.File(filename)

        time = log.get('Time')

        pot = log.get('PotEng')
        pzz = log.get('Pzz')
        temp = log.get('Temp')

        plt.figure(1)
        plt.plot(time, pzz)

        plt.figure(2)
        plt.plot(time, pot, color=get_color_value(float(deformZ), 1.028294, 1.100000, cmap='jet'))
        plt.ylabel('Potential energy (ev)')
        plt.xlabel('deformZ')
        #plt.ylim([-8.43e6, -8.38e6])
        #plt.xlim([100, 500])

        import numpy as np
        pot = pot[200:]
        min_pot = np.min(pot)
        min_pot = np.min(pot[100:])

        plt.figure(3)
        plt.plot(np.min(pzz)/10, min_pot, 'o', color=get_color_value(float(deformZ), 1.028294, 1.100000, cmap='jet'))
        plt.ylabel('Potential energy (ev)')
        plt.xlabel('Initial tensile stress (MPa)')
        #plt.ylim([-8.43e6, -8.38e6])
# Out:
# The pattern contains 1 capturing groups
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30/crack_simulation_deformZ_1.042714/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30/crack_simulation_deformZ_1.053649/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30/crack_simulation_deformZ_1.056894/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30/crack_simulation_deformZ_1.066689/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30/crack_simulation_deformZ_1.050000/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30/crack_simulation_deformZ_1.076575/log.lammps
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/angle_30/crack_simulation_deformZ_1.046351/log.lammps
# ...

# %%
import numpy as np
path = '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200'
pattern = 'crack_simulation_'+floating_number_pattern('deformZ')+'/fracture_displacement.npy'

collection = Collector(path, pattern, fields=('deformZ'))
simulations = collection.get_flat()

system_length = 3000
crack_start_point = 150

for deformZ, path in simulations.items():
        
    filename = path

    data = np.load(filename, allow_pickle=False)
    frames = list(range(0, len(data)))

    filtered_data_crackTip = []
    filtered_data_frames   = []

    for i in range(0, len(data)):
        if data[i] > crack_start_point and data[i] < system_length:
            filtered_data_crackTip.append(data[i])
            filtered_data_frames.append(frames[i])            
    
    for i in range(0, len(filtered_data_frames)):
        if filtered_data_crackTip[i] > 2910:
            print(filename)
            print(filtered_data_frames[i])
            break

    # Find velocity
    timestep = 0.001 # ps
    dump_frequency = 10000

    time_s = []
    time = []
    for i in range(0, len(filtered_data_frames)):
        time.append(filtered_data_frames[i]*timestep*dump_frequency) #Time in ps
        if filtered_data_crackTip[i] < 2000:
            time_s.append(filtered_data_frames[i]*timestep*dump_frequency*(10**-12)) #time in s

    position_m = []
    for i in range(0, len(filtered_data_crackTip)):
        if filtered_data_crackTip[i] < 2000:
            position_m.append(filtered_data_crackTip[i]*(10**-10)) #distance in m

    velocity = np.diff(position_m)/np.diff(time_s)
    mean_velocity = np.mean(velocity)
   
    plt.figure(1)
    plt.plot(filtered_data_frames, filtered_data_crackTip, color=get_color_value(float(deformZ), 1.000000, 1.100000))
    plt.xlabel('Time (ps)')
    plt.ylabel('Position x')
    
    plt.figure(2)
    plt.plot(velocity, color=get_color_value(float(deformZ), 1.00000, 1.10000))
    plt.ylabel('Velocity (m/s)')

    plt.figure(3)
    plt.plot(float(deformZ), mean_velocity, 'o', color=get_color_value(float(deformZ), 1.00000, 1.10000))
    plt.xlabel('deformZ')
    plt.ylabel('Velocity (m/s)')
    
    logfile = '/home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_%s/log.lammps' %deformZ

    log = lammps_logfile.File(logfile)
    pzz = log.get('Pzz')
    min_pressure = np.min(pzz)
    
    pot = log.get('PotEng')
    time = log.get('Time')
    plt.figure(4)
    plt.plot(min_pressure/10, mean_velocity, 'o', color=get_color_value((min_pressure/10), -1600, -3100))
    plt.xlabel('Initial tensile stress (MPa)')
    plt.ylabel('Velocity (m/s)')
        
    min_pot = np.min(pot)
    #pot = pot[200:]
    min_pot_crack = np.min(pot[100:])
    
    delta_up = min_pot_crack - min_pot #eV
    delta_up_J = delta_up * 1.60218e-19 #Joules
    min_pot_J = min_pot * 1.60218e-19 #Joules
    
    plt.figure(5)
    plt.plot(mean_velocity, delta_up, 'o', color=get_color_value(float(deformZ), 1.028294, 1.100000))
    plt.ylabel('Potential energy (J)')
    plt.xlabel('Crack tip velocity (m/s)')
    
    #save_figure('/home/users/marthgg/img/angle30_velocities_vs_potentialEnergy.png')
    if mean_velocity > 100:
        plt.figure(6)
        plt.plot(time/10, pot* 1.60218e-19, color=get_color_value(float(deformZ), 1.028294, 1.100000))#, cmap='jet'))
        plt.axhline(min_pot* 1.60218e-19, color='k', LineStyle='--')
        plt.ylabel('Potential energy (J)')
        plt.xlabel('Time (ps)')
        
        save_figure('/home/users/marthgg/img/noRot_potentialEnergy.png')
# Out:
# The pattern contains 1 capturing groups
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.042714/fracture_displacement.npy
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.053649/fracture_displacement.npy
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.056894/fracture_displacement.npy
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.066689/fracture_displacement.npy
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.050000/fracture_displacement.npy
# /home/users/marthgg/2021_05_simulations_quartz_relaxed_structure/x3000_y200/crack_simulation_deformZ_1.037285/fracture_displacement.npy
# ...

# %%
paths = ['/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.042714/log.lammps', '/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.024721/log.lammps', '/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.021159/log.lammps', '/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.046351/log.lammps', '/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.035479/log.lammps', '/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.031881/log.lammps', '/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.039091/log.lammps', '/home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.028294/log.lammps']

for path in paths:
    filename = path
    log = lammps_logfile.File(filename)
    
    pot = log.get('PotEng')
    
    plt.figure(1)
    plt.plot(pot)

# %%
path = '/home/users/marthgg/simulations/rotated/angle_60'
pattern = 'crack_simulation_'+floating_number_pattern('deformZ')+'/increase_lz/log.lammps'

collection = Collector(path, pattern, fields=('deformZ'))
simulations = collection.get_flat()

for deformZ, path in simulations.items():
    filename = path
    log = lammps_logfile.File(filename)

    pot = log.get('PotEng')

    plt.figure(1)
    plt.plot(pot)
# Out:
# The pattern contains 1 capturing groups
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.042714/increase_lz/log.lammps
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.024721/increase_lz/log.lammps
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.021159/increase_lz/log.lammps
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.046351/increase_lz/log.lammps
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.035479/increase_lz/log.lammps
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.031881/increase_lz/log.lammps
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.039091/increase_lz/log.lammps
# /home/users/marthgg/simulations/rotated/angle_60/crack_simulation_deformZ_1.028294/increase_lz/log.lammps

# %%
path1 = '/home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.021794/log.lammps'
path2 = '/home/users/marthgg/2021_08_quartz_simulations/crack_simulation_deformZ_1.021794/increase_length/log.lammps'

log1 = lammps_logfile.File(path1)
log2 = lammps_logfile.File(path2)

pot1 = log1.get('PotEng')
pot2 = log2.get('PotEng')

time1 = log1.get('Time')
time2 = log2.get('Time')

time = time1[-1]+time2

plt.plot(time1, pot1)
plt.plot(time, pot2)
